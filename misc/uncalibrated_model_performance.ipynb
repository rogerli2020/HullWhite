# %% [markdown]
# ## Uncalibrated model performance

# %%
import pandas as pd
import re
from ZeroRateCurve import ExampleLinearlyInterpolatedZeroRateCurve
from HullWhite import OneFactorHullWhiteModel
from Swaption import EuropeanSwaption, SwaptionType
from HullWhiteTrinomialTree import OneFactorHullWhiteTrinomialTree
from HullWhiteTreeSwaptionPricer import HullWhiteTreeEuropeanSwaptionPricer
import matplotlib.pyplot as plt

# read and filter market quotes data.
df = pd.read_csv("./data/swaption_market_quotes.csv")
df = df.dropna()
df = df[df['Description'].str.contains("EUR Swaption Premium", na=False)]

# function for extracting tenors
def extract_tenors(description):
    matches = re.findall(r'(\d+)([YM])', description.upper())
    tenors = []
    for amount, unit in matches:
        amount = float(amount)
        if unit == 'M':
            amount /= 12 
        tenors.append(amount)
    
    if len(tenors) >= 2:
        return tenors[0], tenors[1]
    elif len(tenors) == 1:
        return tenors[0], None
    else:
        return None, None
    
def price_swaption(hw_model, swap_start, swap_end, timestep):
    zcb_curve = ExampleLinearlyInterpolatedZeroRateCurve()
    swaption = EuropeanSwaption(
        swaption_type=SwaptionType.PAYER,
        expiry=swap_start,
        swap_start=swap_start,
        swap_end=swap_end,
        payment_frequency=0.5,
        notional=1,
        strike=0.00,
        fixed=0.00,
    )

    # compute and set the par swap rates
    swaption.set_ATM_strike_fixed_rate_and_strike(zcb_curve)

    # initialize the tree
    tree = OneFactorHullWhiteTrinomialTree(hw_model, 
                                        swaption.get_valuation_times(), zcb_curve, timestep)
    tree.build_tree(verbose=False)

    # price it!
    pricer = HullWhiteTreeEuropeanSwaptionPricer(tree)
    return pricer.price(swaption) * 10000 # convert to bps

baseline_model = OneFactorHullWhiteModel(a=0.003)
zcb_curve = ExampleLinearlyInterpolatedZeroRateCurve()
errors = []
for index, row in df.iterrows():
    print(f"Current index: {index}, Description: {row["Description"]}")
    swap_start, swap_dur = extract_tenors(row["Description"])
    swap_end = swap_start + swap_dur
    swap_actual_price = row["Quoted_Premium"]
    
    swap_start = round(swap_start, 4)
    swap_end = round(swap_end, 4)
    computed_price = price_swaption(baseline_model, swap_start, swap_end, 0.25)
    
    error = computed_price - swap_actual_price
    errors.append(error)
    print(f"\tComputed Price: {computed_price}; Actual Price: {swap_actual_price}; Error: {error}")
# Out:
# Current index: 0, Description: EUR Swaption Premium 3M10Y
# 	Computed Price: 132.4030017486833; Actual Price: 193.278; Error: -60.8749982513167
# Current index: 2, Description: EUR Swaption Premium 1Y5Y
# 	Computed Price: 177.14180016457797; Actual Price: 206.46; Error: -29.318199835422035
# Current index: 3, Description: EUR Swaption Premium 5Y5Y
# 	Computed Price: 379.11555873594614; Actual Price: 493.6; Error: -114.48444126405388
# Current index: 4, Description: EUR Swaption Premium 1M10Y
# 	Computed Price: 119.27847291906981; Actual Price: 99.786; Error: 19.49247291906981
# Current index: 5, Description: EUR Swaption Premium 2Y20Y
# 	Computed Price: 820.6442804247519; Actual Price: 1078.016; Error: -257.3717195752482
# Current index: 6, Description: EUR Swaption Premium 1Y10Y
# 	Computed Price: 332.7072889751629; Actual Price: 420.059; Error: -87.35171102483713
# Current index: 8, Description: EUR Swaption Premium 5Y10Y
# 	Computed Price: 698.5911336021757; Actual Price: 934.127; Error: -235.5358663978243
# Current index: 9, Description: EUR Swaption Premium 10Y10Y
# 	Computed Price: 832.2908596949416; Actual Price: 1134.896; Error: -302.6051403050584
# Current index: 10, Description: EUR Swaption Premium 10Y20Y
# 	Computed Price: 1415.0486092955887; Actual Price: 1917.635; Error: -502.5863907044113
# Current index: 11, Description: EUR Swaption Premium 3Y15Y
# 	Computed Price: 795.0767900774351; Actual Price: 1033.172; Error: -238.0952099225649
# Current index: 12, Description: EUR Swaption Premium 3M5Y
# 	Computed Price: 70.02173606862591; Actual Price: 92.457; Error: -22.43526393137408
# Current index: 13, Description: EUR Swaption Premium 1Y2Y
# 	Computed Price: 72.76454478121573; Actual Price: 75.295; Error: -2.530455218784269
# Current index: 14, Description: EUR Swaption Premium 2Y10Y
# 	Computed Price: 475.9640843589561; Actual Price: 601.175; Error: -125.21091564104387
# Current index: 15, Description: EUR Swaption Premium 2Y2Y
# 	Computed Price: 105.02517346830612; Actual Price: 119.609; Error: -14.583826531693873
# Current index: 16, Description: EUR Swaption Premium 2Y3Y
# 	Computed Price: 156.03808938902694; Actual Price: 181.604; Error: -25.565910610973077
# Current index: 17, Description: EUR Swaption Premium 3Y10Y
# 	Computed Price: 572.9647129812846; Actual Price: 738.159; Error: -165.19428701871539
# Current index: 18, Description: EUR Swaption Premium 4Y10Y
# 	Computed Price: 644.4051462024837; Actual Price: 849.079; Error: -204.67385379751624
# Current index: 19, Description: EUR Swaption Premium 5Y15Y
# 	Computed Price: 966.4755608984085; Actual Price: 1288.4351; Error: -321.9595391015914
# Current index: 20, Description: EUR Swaption Premium 6Y10Y
# 	Computed Price: 742.9122162036812; Actual Price: 982.0001; Error: -239.0878837963188
# Current index: 21, Description: EUR Swaption Premium 7Y10Y
# 	Computed Price: 775.2354982646198; Actual Price: 1052.174; Error: -276.9385017353802
# Current index: 22, Description: EUR Swaption Premium 8Y10Y
# 	Computed Price: 798.3789414962708; Actual Price: 1072.0001; Error: -273.62115850372913
# Current index: 23, Description: EUR Swaption Premium 9Y10Y
# 	Computed Price: 814.4222157453373; Actual Price: 1099.0001; Error: -284.57788425466265
# Current index: 24, Description: EUR Swaption Premium 1M20Y
# 	Computed Price: 204.79464810042327; Actual Price: 194.601; Error: 10.193648100423275
# Current index: 25, Description: EUR Swaption Premium 2M15Y
# 	Computed Price: 33.77025695094382; Actual Price: 222.264; Error: -188.4937430490562
# Current index: 26, Description: EUR Swaption Premium 3M30Y
# 	Computed Price: 305.93108161574816; Actual Price: 539.028; Error: -233.09691838425186
# Current index: 27, Description: EUR Swaption Premium 6M5Y
# 	Computed Price: 115.97775503528284; Actual Price: 135.099; Error: -19.12124496471715
# Current index: 28, Description: EUR Swaption Premium 6M6Y
# 	Computed Price: 137.8223539178987; Actual Price: 164.374; Error: -26.551646082101286
# Current index: 29, Description: EUR Swaption Premium 10Y30Y
# 	Computed Price: 1808.0555506782882; Actual Price: 2528.1389; Error: -720.0833493217117
# Current index: 31, Description: EUR Swaption Premium 15Y15Y
# 	Computed Price: 1173.3984774731662; Actual Price: 1524.369; Error: -350.97052252683375
# Current index: 33, Description: EUR Swaption Premium 1Y15Y
# 	Computed Price: 463.70976137172704; Actual Price: 602.302; Error: -138.59223862827298
# Current index: 34, Description: EUR Swaption Premium 1Y20Y
# 	Computed Price: 576.7512250923528; Actual Price: 771.86; Error: -195.10877490764722
# Current index: 35, Description: EUR Swaption Premium 1Y25Y
# 	Computed Price: 673.8516536418424; Actual Price: 929.656; Error: -255.80434635815755
# Current index: 36, Description: EUR Swaption Premium 1Y3Y
# 	Computed Price: 108.24977708429279; Actual Price: 118.892; Error: -10.642222915707208
# Current index: 37, Description: EUR Swaption Premium 1Y30Y
# 	Computed Price: 755.9151857562917; Actual Price: 1076.843; Error: -320.9278142437083
# Current index: 38, Description: EUR Swaption Premium 1Y4Y
# 	Computed Price: 143.0016526091033; Actual Price: 162.101; Error: -19.099347390896696
# Current index: 40, Description: EUR Swaption Premium 1Y6Y
# 	Computed Price: 210.1910118598771; Actual Price: 248.829; Error: -38.6379881401229
# Current index: 41, Description: EUR Swaption Premium 1Y7Y
# 	Computed Price: 242.222187386135; Actual Price: 291.292; Error: -49.06981261386497
# Current index: 42, Description: EUR Swaption Premium 1Y8Y
# 	Computed Price: 273.37511052572455; Actual Price: 333.827; Error: -60.45188947427545
# Current index: 43, Description: EUR Swaption Premium 1Y9Y
# 	Computed Price: 303.47556588113963; Actual Price: 376.73; Error: -73.25443411886039
# Current index: 45, Description: EUR Swaption Premium 2Y15Y
# 	Computed Price: 661.7266195950966; Actual Price: 850.743; Error: -189.01638040490343
# Current index: 46, Description: EUR Swaption Premium 2Y25Y
# 	Computed Price: 954.9631928574544; Actual Price: 1282.48; Error: -327.51680714254564
# Current index: 47, Description: EUR Swaption Premium 2Y30Y
# 	Computed Price: 1068.1754314952063; Actual Price: 1485.668; Error: -417.49256850479355
# Current index: 48, Description: EUR Swaption Premium 2Y4Y
# 	Computed Price: 206.09645642246116; Actual Price: 243.745; Error: -37.648543577538845
# Current index: 50, Description: EUR Swaption Premium 2Y5Y
# 	Computed Price: 254.65689826619; Actual Price: 306.589; Error: -51.932101733809986
# Current index: 51, Description: EUR Swaption Premium 2Y6Y
# 	Computed Price: 301.7428217392812; Actual Price: 365.094; Error: -63.35117826071877
# Current index: 52, Description: EUR Swaption Premium 2Y7Y
# 	Computed Price: 347.5077752110773; Actual Price: 423.812; Error: -76.30422478892274
# Current index: 53, Description: EUR Swaption Premium 2Y8Y
# 	Computed Price: 391.72850432679735; Actual Price: 482.986; Error: -91.25749567320264
# Current index: 54, Description: EUR Swaption Premium 2Y9Y
# 	Computed Price: 434.6317957022802; Actual Price: 542.125; Error: -107.49320429771979
# Current index: 57, Description: EUR Swaption Premium 3Y2Y
# 	Computed Price: 127.48181720158512; Actual Price: 155.238; Error: -27.756182798414883
# Current index: 58, Description: EUR Swaption Premium 3Y20Y
# 	Computed Price: 983.4388881152117; Actual Price: 1307.859; Error: -324.4201118847882
# Current index: 59, Description: EUR Swaption Premium 3Y25Y
# 	Computed Price: 1140.027624533227; Actual Price: 1555.9301; Error: -415.902475466773
# Current index: 60, Description: EUR Swaption Premium 3Y3Y
# 	Computed Price: 189.35513859786178; Actual Price: 231.217; Error: -41.86186140213823
# Current index: 61, Description: EUR Swaption Premium 3Y30Y
# 	Computed Price: 1271.8915499157615; Actual Price: 1790.983; Error: -519.0914500842384
# Current index: 62, Description: EUR Swaption Premium 3Y4Y
# 	Computed Price: 249.51674252174382; Actual Price: 306.807; Error: -57.290257478256194
# Current index: 64, Description: EUR Swaption Premium 3Y5Y
# 	Computed Price: 307.89215579477025; Actual Price: 383.592; Error: -75.69984420522974
# Current index: 65, Description: EUR Swaption Premium 3Y6Y
# 	Computed Price: 364.60736127018544; Actual Price: 455.781; Error: -91.17363872981457
# Current index: 66, Description: EUR Swaption Premium 3Y7Y
# 	Computed Price: 419.424783152694; Actual Price: 526.393; Error: -106.96821684730605
# Current index: 67, Description: EUR Swaption Premium 3Y8Y
# 	Computed Price: 472.5719842110849; Actual Price: 597.584; Error: -125.01201578891505
# Current index: 68, Description: EUR Swaption Premium 3Y9Y
# 	Computed Price: 523.7729844755083; Actual Price: 667.749; Error: -143.9760155244917
# Current index: 71, Description: EUR Swaption Premium 4Y15Y
# 	Computed Price: 892.7546444551871; Actual Price: 1171.999; Error: -279.24435554481295
# Current index: 72, Description: EUR Swaption Premium 4Y2Y
# 	Computed Price: 144.649793290445; Actual Price: 182.169; Error: -37.51920670955502
# Current index: 73, Description: EUR Swaption Premium 4Y20Y
# 	Computed Price: 1101.3435780807417; Actual Price: 1484.0389; Error: -382.6953219192583
# Current index: 74, Description: EUR Swaption Premium 4Y25Y
# 	Computed Price: 1271.6766257039985; Actual Price: 1760.734; Error: -489.0573742960014
# Current index: 75, Description: EUR Swaption Premium 4Y3Y
# 	Computed Price: 214.419908449798; Actual Price: 269.312; Error: -54.892091550202025
# Current index: 76, Description: EUR Swaption Premium 4Y30Y
# 	Computed Price: 1415.1428875601691; Actual Price: 2023.3521; Error: -608.2092124398309
# Current index: 77, Description: EUR Swaption Premium 4Y4Y
# 	Computed Price: 282.17180616797134; Actual Price: 358.002; Error: -75.83019383202867
# Current index: 79, Description: EUR Swaption Premium 4Y5Y
# 	Computed Price: 347.97756890295165; Actual Price: 444.722; Error: -96.74443109704833
# Current index: 80, Description: EUR Swaption Premium 4Y6Y
# 	Computed Price: 411.6056376326937; Actual Price: 527.172; Error: -115.56636236730634
# Current index: 81, Description: EUR Swaption Premium 4Y7Y
# 	Computed Price: 473.2585919285087; Actual Price: 609.55; Error: -136.29140807149128
# Current index: 82, Description: EUR Swaption Premium 4Y8Y
# 	Computed Price: 532.6592222355395; Actual Price: 690.826; Error: -158.16677776446056
# Current index: 83, Description: EUR Swaption Premium 4Y9Y
# 	Computed Price: 589.7298126351433; Actual Price: 771.677; Error: -181.94718736485675
# Current index: 86, Description: EUR Swaption Premium 5Y2Y
# 	Computed Price: 158.09594405861978; Actual Price: 203.508; Error: -45.41205594138023
# Current index: 87, Description: EUR Swaption Premium 5Y20Y
# 	Computed Price: 1189.1034948084698; Actual Price: 1616.671; Error: -427.56750519153024
# Current index: 88, Description: EUR Swaption Premium 5Y25Y
# 	Computed Price: 1367.4471844503141; Actual Price: 1924.135; Error: -556.6878155496859
# Current index: 89, Description: EUR Swaption Premium 5Y3Y
# 	Computed Price: 234.03496835999815; Actual Price: 301.91; Error: -67.87503164000188
# Current index: 90, Description: EUR Swaption Premium 5Y30Y
# 	Computed Price: 1517.8780861205155; Actual Price: 2198.582; Error: -680.7039138794844
# Current index: 91, Description: EUR Swaption Premium 5Y4Y
# 	Computed Price: 307.77855621458957; Actual Price: 398.423; Error: -90.64444378541043
# Current index: 93, Description: EUR Swaption Premium 5Y6Y
# 	Computed Price: 448.20449557488945; Actual Price: 585.714; Error: -137.5095044251106
# Current index: 94, Description: EUR Swaption Premium 5Y7Y
# 	Computed Price: 514.7817916884446; Actual Price: 675.008; Error: -160.2262083115554
# Current index: 95, Description: EUR Swaption Premium 5Y8Y
# 	Computed Price: 578.7548348658115; Actual Price: 763.603; Error: -184.84816513418843
# Current index: 96, Description: EUR Swaption Premium 5Y9Y
# 	Computed Price: 640.0456835572227; Actual Price: 851.325; Error: -211.27931644277737
# Current index: 99, Description: EUR Swaption Premium 6Y15Y
# 	Computed Price: 1024.8512086995127; Actual Price: 1348.0001; Error: -323.1488913004873
# Current index: 100, Description: EUR Swaption Premium 6Y2Y
# 	Computed Price: 169.09995943889032; Actual Price: 220.992; Error: -51.89204056110967
# Current index: 101, Description: EUR Swaption Premium 6Y20Y
# 	Computed Price: 1256.1202285445288; Actual Price: 1679.0002; Error: -422.87997145547115
# Current index: 102, Description: EUR Swaption Premium 6Y25Y
# 	Computed Price: 1440.594423301616; Actual Price: 1983.0002; Error: -542.405776698384
# Current index: 103, Description: EUR Swaption Premium 6Y3Y
# 	Computed Price: 250.07166318459974; Actual Price: 322.956; Error: -72.88433681540027
# Current index: 104, Description: EUR Swaption Premium 6Y30Y
# 	Computed Price: 1613.5345852291532; Actual Price: 2254.0002; Error: -640.4656147708467
# Current index: 105, Description: EUR Swaption Premium 6Y4Y
# 	Computed Price: 328.44743011017636; Actual Price: 427.4841; Error: -99.03666988982366
# Current index: 106, Description: EUR Swaption Premium 6Y5Y
# 	Computed Price: 404.3261238103834; Actual Price: 532.17; Error: -127.84387618961654
# Current index: 107, Description: EUR Swaption Premium 6Y6Y
# 	Computed Price: 477.4692140736769; Actual Price: 620.0001; Error: -142.5308859263231
# Current index: 108, Description: EUR Swaption Premium 6Y7Y
# 	Computed Price: 547.7684918074002; Actual Price: 712.0001; Error: -164.23160819259977
# Current index: 109, Description: EUR Swaption Premium 6Y8Y
# 	Computed Price: 615.132563340269; Actual Price: 804.0001; Error: -188.86753665973094
# Current index: 110, Description: EUR Swaption Premium 6Y9Y
# 	Computed Price: 679.4869450740076; Actual Price: 894.0001; Error: -214.51315492599235
# Current index: 113, Description: EUR Swaption Premium 7Y15Y
# 	Computed Price: 1066.2358351625169; Actual Price: 1434.7889; Error: -368.55306483748313
# Current index: 114, Description: EUR Swaption Premium 7Y2Y
# 	Computed Price: 177.42064357320848; Actual Price: 235.233; Error: -57.812356426791524
# Current index: 115, Description: EUR Swaption Premium 7Y20Y
# 	Computed Price: 1304.814185591283; Actual Price: 1789.016; Error: -484.20181440871715
# Current index: 116, Description: EUR Swaption Premium 7Y25Y
# 	Computed Price: 1516.7658832765183; Actual Price: 2107.3101; Error: -590.5442167234819
# Current index: 117, Description: EUR Swaption Premium 7Y3Y
# 	Computed Price: 262.07701895712074; Actual Price: 346.348; Error: -84.27098104287927
# Current index: 118, Description: EUR Swaption Premium 7Y30Y
# 	Computed Price: 1695.5863718127493; Actual Price: 2397.6001; Error: -702.0137281872508
# Current index: 119, Description: EUR Swaption Premium 7Y4Y
# 	Computed Price: 344.01063944258783; Actual Price: 455.573; Error: -111.56236055741215
# Current index: 121, Description: EUR Swaption Premium 7Y5Y
# 	Computed Price: 423.01742239955274; Actual Price: 562.584; Error: -139.5665776004472
# Current index: 122, Description: EUR Swaption Premium 7Y6Y
# 	Computed Price: 498.97298737219194; Actual Price: 669.755; Error: -170.78201262780806
# Current index: 123, Description: EUR Swaption Premium 7Y7Y
# 	Computed Price: 571.7718760687749; Actual Price: 775.249; Error: -203.47712393122515
# Current index: 124, Description: EUR Swaption Premium 7Y8Y
# 	Computed Price: 641.3276919232219; Actual Price: 871.617; Error: -230.28930807677807
# Current index: 125, Description: EUR Swaption Premium 7Y9Y
# 	Computed Price: 709.6103221808936; Actual Price: 961.308; Error: -251.6976778191064
# Current index: 128, Description: EUR Swaption Premium 8Y15Y
# 	Computed Price: 1097.1507313636475; Actual Price: 1461.0001; Error: -363.84936863635244
# Current index: 129, Description: EUR Swaption Premium 8Y2Y
# 	Computed Price: 183.6782487781126; Actual Price: 246.161; Error: -62.48275122188741
# Current index: 130, Description: EUR Swaption Premium 8Y20Y
# 	Computed Price: 1357.1234755044593; Actual Price: 1810.0002; Error: -452.87672449554066
# Current index: 131, Description: EUR Swaption Premium 8Y25Y
# 	Computed Price: 1572.4466076336478; Actual Price: 2121.0002; Error: -548.5535923663522
# Current index: 132, Description: EUR Swaption Premium 8Y3Y
# 	Computed Price: 271.1543436091684; Actual Price: 360.297; Error: -89.14265639083163
# Current index: 133, Description: EUR Swaption Premium 8Y30Y
# 	Computed Price: 1749.7350055443073; Actual Price: 2396.0002; Error: -646.2651944556926
# Current index: 134, Description: EUR Swaption Premium 8Y4Y
# 	Computed Price: 355.5404595245085; Actual Price: 473.6401; Error: -118.09964047549153
# Current index: 135, Description: EUR Swaption Premium 8Y5Y
# 	Computed Price: 436.69520858855196; Actual Price: 584.2861; Error: -147.59089141144807
# Current index: 136, Description: EUR Swaption Premium 8Y6Y
# 	Computed Price: 514.4982091888282; Actual Price: 680.0001; Error: -165.50189081117173
# Current index: 137, Description: EUR Swaption Premium 8Y7Y
# 	Computed Price: 588.8502864574288; Actual Price: 781.0001; Error: -192.14981354257122
# Current index: 138, Description: EUR Swaption Premium 8Y8Y
# 	Computed Price: 661.5640199083698; Actual Price: 879.0001; Error: -217.43608009163017
# Current index: 139, Description: EUR Swaption Premium 8Y9Y
# 	Computed Price: 731.4092492100848; Actual Price: 977.0001; Error: -245.59085078991518
# Current index: 142, Description: EUR Swaption Premium 9Y15Y
# 	Computed Price: 1131.9932165452212; Actual Price: 1494.0001; Error: -362.00688345477874
# Current index: 143, Description: EUR Swaption Premium 9Y2Y
# 	Computed Price: 188.4517694463012; Actual Price: 255.846; Error: -67.3942305536988
# Current index: 144, Description: EUR Swaption Premium 9Y20Y
# 	Computed Price: 1393.5574411633988; Actual Price: 1850.0002; Error: -456.4427588366011
# Current index: 145, Description: EUR Swaption Premium 9Y25Y
# 	Computed Price: 1609.4363817531744; Actual Price: 2158.0002; Error: -548.5638182468256
# Current index: 146, Description: EUR Swaption Premium 9Y3Y
# 	Computed Price: 277.8924088170295; Actual Price: 373.345; Error: -95.45259118297054
# Current index: 147, Description: EUR Swaption Premium 9Y30Y
# 	Computed Price: 1782.5979271972135; Actual Price: 2436.0002; Error: -653.4022728027865
# Current index: 148, Description: EUR Swaption Premium 9Y4Y
# 	Computed Price: 363.94556329086447; Actual Price: 489.2301; Error: -125.28453670913552
# Current index: 149, Description: EUR Swaption Premium 9Y5Y
# 	Computed Price: 446.47486621596073; Actual Price: 601.1431; Error: -154.66823378403927
# Current index: 150, Description: EUR Swaption Premium 9Y6Y
# 	Computed Price: 525.3673015267193; Actual Price: 699.0001; Error: -173.63279847328067
# Current index: 151, Description: EUR Swaption Premium 9Y7Y
# 	Computed Price: 602.2382670447853; Actual Price: 802.0001; Error: -199.7618329552147
# Current index: 152, Description: EUR Swaption Premium 9Y8Y
# 	Computed Price: 676.0436458116674; Actual Price: 903.0001; Error: -226.9564541883326
# Current index: 153, Description: EUR Swaption Premium 9Y9Y
# 	Computed Price: 746.7720649898797; Actual Price: 1002.0001; Error: -255.22803501012027
# Current index: 155, Description: EUR Swaption Premium 1M15Y
# 	Computed Price: 162.17847642597383; Actual Price: 148.611; Error: 13.567476425973837
# Current index: 156, Description: EUR Swaption Premium 1M2Y
# 	Computed Price: 32.652230809996446; Actual Price: 14.187; Error: 18.46523080999645
# Current index: 157, Description: EUR Swaption Premium 1M25Y
# 	Computed Price: 247.19741626112375; Actual Price: 242.167; Error: 5.030416261123747
# Current index: 158, Description: EUR Swaption Premium 1M3Y
# 	Computed Price: 46.52723855679119; Actual Price: 24.333; Error: 22.19423855679119
# Current index: 159, Description: EUR Swaption Premium 1M30Y
# 	Computed Price: 285.16514835174604; Actual Price: 289.852; Error: -4.686851648253935
# Current index: 160, Description: EUR Swaption Premium 1M4Y
# 0.0833 5.0833 dict_keys([0, 0.0833, 0.25, 0.5, 0.5833, 0.75, 1.0, 1.0833, 1.25, 1.5, 1.5833, 1.75, 2.0, 2.0833, 2.25, 2.5, 2.5833, 2.75, 3.0, 3.0833, 3.25, 3.5, 3.5833, 3.75, 4.0, 4.0833, 4.25, 4.5, 4.5833])
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 68
#      66 swap_start = round(swap_start, 4)
#      67 swap_end = round(swap_end, 4)
# ---> 68 computed_price = price_swaption(baseline_model, swap_start, swap_end, 0.25)
#      70 error = computed_price - swap_actual_price
#      71 errors.append(error)
#
# Cell In[1], line 55, in price_swaption(hw_model, swap_start, swap_end, timestep)
#      53 # price it!
#      54 pricer = HullWhiteTreeEuropeanSwaptionPricer(tree)
# ---> 55 return pricer.price(swaption) * 10000
#
# File c:\Users\rogli\Desktop\hullWhite\HullWhiteTreeSwaptionPricer.py:51, in HullWhiteTreeEuropeanSwaptionPricer.price(self, swaption)
#      49 fixed_leg = 0.0
#      50 for T in swaption.get_fixed_leg_payment_times():
# ---> 51     this_P = HullWhiteTreeUtil.get_node_specific_zcb_price(self.tree, node, T)
#      52     fixed_leg += this_P # assume tau is just 1.
#      53 fixed_leg *= swaption.fixed
#
# File c:\Users\rogli\Desktop\hullWhite\HullWhiteTreeUtil.py:106, in HullWhiteTreeUtil.get_node_specific_zcb_price(tree, node, T)
#     104 T = round(T, 4)
#     105 t0: float = node.layer_attr.t
# --> 106 zcb_dict = HullWhiteTreeUtil.get_zcb_price_dict(tree, t0, T)
#     107 return zcb_dict[ (node.layer_attr.layer_id, node.j) ]
#
# File c:\Users\rogli\Desktop\hullWhite\HullWhiteTreeUtil.py:32, in HullWhiteTreeUtil.get_zcb_price_dict(tree, t0, T, maturity_node_values)
#      30 if t0 not in tree.t_to_layer or T not in tree.t_to_layer:
#      31     print(t0, T, tree.t_to_layer.keys())
# ---> 32     raise Exception(f"Invalid t0 or T for the given tree.")
#      33 if t0 > T:
#      34     raise Exception(f"t0 cannot be greater than or equal to T.")
#
# Exception: Invalid t0 or T for the given tree.

# %%
plt.figure(figsize=(8,5))
plt.hist(errors, bins=100, color='skyblue', edgecolor='black')
plt.xlabel("Pricing Error")
plt.ylabel("Frequency")
plt.title("Distribution of Swaption Pricing Errors")
plt.show()

# %% [markdown]
# Looks like the errors are mostly negative? Curious!! Perhaps it's the result of underestimating the sigma by assuming it's a constant 0.01!

# %%
errors
# Out:
# [np.float64(-60.8749982513167),
#  np.float64(-29.318199835422035),
#  np.float64(-114.48444126405388),
#  np.float64(19.49247291906981),
#  np.float64(-257.3717195752482),
#  np.float64(-87.35171102483713),
#  np.float64(-235.5358663978243),
#  np.float64(-302.6051403050584),
#  np.float64(-502.5863907044113),
#  np.float64(-238.0952099225649),
#  np.float64(-22.43526393137408),
#  np.float64(-2.530455218784269),
#  np.float64(-125.21091564104387),
#  np.float64(-14.583826531693873),
#  np.float64(-25.565910610973077),
#  np.float64(-165.19428701871539),
#  np.float64(-204.67385379751624),
#  np.float64(-321.9595391015914),
#  np.float64(-239.0878837963188),
#  np.float64(-276.9385017353802),
#  np.float64(-273.62115850372913),
#  np.float64(-284.57788425466265),
#  np.float64(10.193648100423275),
#  np.float64(-188.4937430490562),
#  np.float64(-233.09691838425186),
#  np.float64(-19.12124496471715),
#  np.float64(-26.551646082101286),
#  np.float64(-720.0833493217117),
#  np.float64(-350.97052252683375),
#  np.float64(-138.59223862827298),
#  np.float64(-195.10877490764722),
#  np.float64(-255.80434635815755),
#  np.float64(-10.642222915707208),
#  np.float64(-320.9278142437083),
#  np.float64(-19.099347390896696),
#  np.float64(-38.6379881401229),
#  np.float64(-49.06981261386497),
#  np.float64(-60.45188947427545),
#  np.float64(-73.25443411886039),
#  np.float64(-189.01638040490343),
#  np.float64(-327.51680714254564),
#  np.float64(-417.49256850479355),
#  np.float64(-37.648543577538845),
#  np.float64(-51.932101733809986),
#  np.float64(-63.35117826071877),
#  np.float64(-76.30422478892274),
#  np.float64(-91.25749567320264),
#  np.float64(-107.49320429771979),
#  np.float64(-27.756182798414883),
#  np.float64(-324.4201118847882),
#  np.float64(-415.902475466773),
#  np.float64(-41.86186140213823),
#  np.float64(-519.0914500842384),
#  np.float64(-57.290257478256194),
#  np.float64(-75.69984420522974),
#  np.float64(-91.17363872981457),
#  np.float64(-106.96821684730605),
#  np.float64(-125.01201578891505),
#  np.float64(-143.9760155244917),
#  np.float64(-279.24435554481295),
#  np.float64(-37.51920670955502),
#  np.float64(-382.6953219192583),
#  np.float64(-489.0573742960014),
#  np.float64(-54.892091550202025),
#  np.float64(-608.2092124398309),
#  np.float64(-75.83019383202867),
#  np.float64(-96.74443109704833),
#  np.float64(-115.56636236730634),
#  np.float64(-136.29140807149128),
#  np.float64(-158.16677776446056),
#  np.float64(-181.94718736485675),
#  np.float64(-45.41205594138023),
#  np.float64(-427.56750519153024),
#  np.float64(-556.6878155496859),
#  np.float64(-67.87503164000188),
#  np.float64(-680.7039138794844),
#  np.float64(-90.64444378541043),
#  np.float64(-137.5095044251106),
#  np.float64(-160.2262083115554),
#  np.float64(-184.84816513418843),
#  np.float64(-211.27931644277737),
#  np.float64(-323.1488913004873),
#  np.float64(-51.89204056110967),
#  np.float64(-422.87997145547115),
#  np.float64(-542.405776698384),
#  np.float64(-72.88433681540027),
#  np.float64(-640.4656147708467),
#  np.float64(-99.03666988982366),
#  np.float64(-127.84387618961654),
#  np.float64(-142.5308859263231),
#  np.float64(-164.23160819259977),
#  np.float64(-188.86753665973094),
#  np.float64(-214.51315492599235),
#  np.float64(-368.55306483748313),
#  np.float64(-57.812356426791524),
#  np.float64(-484.20181440871715),
#  np.float64(-590.5442167234819),
#  np.float64(-84.27098104287927),
#  np.float64(-702.0137281872508),
#  np.float64(-111.56236055741215),
#  np.float64(-139.5665776004472),
#  np.float64(-170.78201262780806),
#  np.float64(-203.47712393122515),
#  np.float64(-230.28930807677807),
#  np.float64(-251.6976778191064),
#  np.float64(-363.84936863635244),
#  np.float64(-62.48275122188741),
#  np.float64(-452.87672449554066),
#  np.float64(-548.5535923663522),
#  np.float64(-89.14265639083163),
#  np.float64(-646.2651944556926),
#  np.float64(-118.09964047549153),
#  np.float64(-147.59089141144807),
#  np.float64(-165.50189081117173),
#  np.float64(-192.14981354257122),
#  np.float64(-217.43608009163017),
#  np.float64(-245.59085078991518),
#  np.float64(-362.00688345477874),
#  np.float64(-67.3942305536988),
#  np.float64(-456.4427588366011),
#  np.float64(-548.5638182468256),
#  np.float64(-95.45259118297054),
#  np.float64(-653.4022728027865),
#  np.float64(-125.28453670913552),
#  np.float64(-154.66823378403927),
#  np.float64(-173.63279847328067),
#  np.float64(-199.7618329552147),
#  np.float64(-226.9564541883326),
#  np.float64(-255.22803501012027),
#  np.float64(13.567476425973837),
#  np.float64(18.46523080999645),
#  np.float64(5.030416261123747),
#  np.float64(22.19423855679119),
#  np.float64(-4.686851648253935)]
